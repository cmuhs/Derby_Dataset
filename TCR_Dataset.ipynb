# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Jockey and Trainer columns are intermingled. EX Bob baffert is only a trainer
df1 = pd.read_csv('TrackConditions.csv')
df2 = pd.read_csv('TripleCrownRaces_2005-2019.csv')

# %%
df1.head()
# Out:
#    year  high_temp  low_temp  precipitation_24hrs  weather track_condition  \
# 0  2019       71.0      58.0                 0.34  Showery          Sloppy
# 1  2018       70.0      61.0                 3.15  Showery          Sloppy
# 2  2017       62.0      42.0                 0.12    Clear           Muddy
# 3  2016       85.0      59.0                 0.28    Clear            Fast
# 4  2015       79.0      52.0                 0.00    Clear            Fast
#
#    attendance            race
# 0      150729  Kentucky Derby
# 1      157813  Kentucky Derby
# 2      158070  Kentucky Derby
# 3      167227  Kentucky Derby
# 4      170513  Kentucky Derby

# %%
df2.head()
# Out:
#    final_place  PP             Horse              Jockey            Trainer  \
# 0            1  10           Giacomo          Mike Smith     John Shirreffs
# 1            2  18  Closing Argument  Cornelio Velasquez  Kiaran McLaughlin
# 2            3  12       Afleet Alex              J Rose        Tim Ritchey
# 3            4  17     Don't Get Mad            T C Baze       Ronald Ellis
# 4            5  20      Buzzards Bay         Mark Guidry       Jeff Mullins
#
#    Odds    Win  Place  Show  year            race
# 0  51.0  102.6   45.8  19.8  2005  Kentucky Derby
# 1  72.0    0.0   70.0  24.8  2005  Kentucky Derby
# 2   5.5    0.0    0.0   4.6  2005  Kentucky Derby
# 3  30.0    0.0    0.0   0.0  2005  Kentucky Derby
# 4  47.0    0.0    0.0   0.0  2005  Kentucky Derby

# %%
df3 = pd.merge(df1, df2, on=['race', 'year'])
df3.tail()
#df3.dtypes
# Out:
#      year  high_temp  low_temp  precipitation_24hrs weather track_condition  \
# 622  2005       73.0      48.9                  0.0   Clear            Fast
# 623  2005       73.0      48.9                  0.0   Clear            Fast
# 624  2005       73.0      48.9                  0.0   Clear            Fast
# 625  2005       73.0      48.9                  0.0   Clear            Fast
# 626  2005       73.0      48.9                  0.0   Clear            Fast
#
#      attendance       race  final_place  PP             Horse  \
# 622      125687  Preakness           10   2          High Fly
# 623      125687  Preakness           11   6       Hal's Image
# 624      125687  Preakness           12   9             Wilko
# 625      125687  Preakness           13   5  Galloping Grocer
# 626      125687  Preakness           14  14        Going Wild
#
#               Jockey             Trainer  Odds  Win  Place  Show
# 622  Jerry D. Bailey           Nick Zito  12.0  0.0    0.0   0.0
# 623      Jose Santos       Barry R. Rose  16.0  0.0    0.0   0.0
# 624   Corey Kakatani      D. Wayne Lukas  14.0  0.0    0.0   0.0
# 625        Joe Bravo  Dominick Schettino  28.0  0.0    0.0   0.0
# 626   Robby Albarado      D. Wayne Lukas  27.0  0.0    0.0   0.0

# %%
banana = df3[(df3['race'] == 'Kentucky Derby') & (df3['year'] == 2019)]
# 2           William I. Mott           Jose Ortiz  11.0    0.0    0.0   5.6
# 3               Bob Baffert       Irad Ortiz Jr.   7.0    0.0    0.0   0.0
# 4               Bob Baffert         Joel Rosario   6.0    0.0    0.0   0.0
# 5                 Tsunoda K      Julien Leparoux  51.0    0.0    0.0   0.0
# 6             Mark E. Casse     Tyler Gaffalione  21.0    0.0    0.0   0.0
# 7          Brendan P. Walsh  Ricardo Santana Jr.  31.0    0.0    0.0   0.0
# 8      Michael J. Trombetta      Julian Pimentel  16.0    0.0    0.0   0.0
# 9          Todd A. Pletcher      Corey J Lanerie  31.0    0.0    0.0   0.0
# 10          W. Bret Calhoun         Gabriel Saez  21.0    0.0    0.0   0.0
# 11            George Weaver    Javier Castellano  21.0    0.0    0.0   0.0
# 12          Gustavo Delgado       Chris Landeros  21.0    0.0    0.0   0.0
# 13             Danny Gargan      Junior Alvarado  21.0    0.0    0.0   0.0
# 14              Bob Baffert       Florent Geroux   7.0    0.0    0.0   0.0
# 15       Steven M. Asmussen            Jon Court  31.0    0.0    0.0   0.0
# 16             Jason Servis            Luis Saez  11.0    0.0    0.0   0.0
# 17            Todd Pletcher         Manny Franco  31.0    0.0    0.0   0.0
# 18             Peter Miller     Drayden Van Dyke  51.0    0.0    0.0   0.0
# 19     Kiaran P. McLaughlin         Rajiv Maragh   NaN    0.0    0.0   0.0
# 20      Richard E. Mandella           Mike Smith   NaN    0.0    0.0   0.0

# %% [markdown]
# How often did a singular jockey win when the precipitation_24hrs was high?

# %%
#how often a singular jockey won, but how do I apply
#df3.loc[df3.final_place == 1, 'Jockey'].value_counts().loc[lambda x : x==1]
high_precip = df3.loc[(df3['precipitation_24hrs'] >= 2) & (df3['final_place'] == 1)]
display(high_precip)
# Out:
#      year  high_temp  low_temp  precipitation_24hrs  weather track_condition  \
# 21   2018       70.0      61.0                 3.15  Showery          Sloppy
# 365  2013       75.9      57.0                 4.11    Clear            Fast
#
#      attendance            race  final_place  PP          Horse       Jockey  \
# 21       157813  Kentucky Derby            1   7        Justify  Bob Baffert
# 365       55779  Belmont Stakes            1  12  Palace Malice   Mike Smith
#
#            Trainer  Odds   Win  Place  Show  avg_temp
# 21      Mike Smith   3.5   7.8    6.0   4.4     65.50
# 365  Todd Pletcher  16.0  29.6   11.2   6.7     66.45

# %% [markdown]
# What was the average temp on race days?

# %%
df3['avg_temp'] = df3[['high_temp', 'low_temp']].mean(axis=1)
df3.tail()
# Out:
#      year  high_temp  low_temp  precipitation_24hrs weather track_condition  \
# 622  2005       73.0      48.9                  0.0   Clear            Fast
# 623  2005       73.0      48.9                  0.0   Clear            Fast
# 624  2005       73.0      48.9                  0.0   Clear            Fast
# 625  2005       73.0      48.9                  0.0   Clear            Fast
# 626  2005       73.0      48.9                  0.0   Clear            Fast
#
#      attendance       race  final_place  PP             Horse  \
# 622      125687  Preakness           10   2          High Fly
# 623      125687  Preakness           11   6       Hal's Image
# 624      125687  Preakness           12   9             Wilko
# 625      125687  Preakness           13   5  Galloping Grocer
# 626      125687  Preakness           14  14        Going Wild
#
#               Jockey             Trainer  Odds  Win  Place  Show  avg_temp
# 622  Jerry D. Bailey           Nick Zito  12.0  0.0    0.0   0.0     60.95
# 623      Jose Santos       Barry R. Rose  16.0  0.0    0.0   0.0     60.95
# 624   Corey Kakatani      D. Wayne Lukas  14.0  0.0    0.0   0.0     60.95
# 625        Joe Bravo  Dominick Schettino  28.0  0.0    0.0   0.0     60.95
# 626   Robby Albarado      D. Wayne Lukas  27.0  0.0    0.0   0.0     60.95

# %% [markdown]
# How often did a singular jockey win?

# %%
df3.loc[df3.final_place == 1, 'Jockey'].value_counts().loc[lambda x : x==1]
#df2.loc[df2['']]
# Out:
# Kelly Breen            1
# Doug F. O'Neill        1
# Chad Brown             1
# Flavien Prat           1
# William Mott           1
# Art Sherman            1
# Bennie Wooley Jr.      1
# Kiaran McLaughlin      1
# Michael Matz           1
# Tom Albertrani         1
#  Art Sherman           1
# John Shirreffs         1
# Shug McGaughey         1
# Richard Dutrow Jr.     1
# Mike Matz              1
# Nick Zito              1
# Mike Smith             1
# Joel Rosario           1
# Tim Ice                1
# J. Keith Desormeaux    1
# D. Wayne Lukas         1
# Christophe Clement     1
# Tyler Gaffalione       1
# Graham Motion          1
# Richard Dutrow, Jr.    1
# Todd A. Pletcher       1
# Carl Nafzger           1
# Tim Ritchey            1
# Dale Romans            1
# Timothy F. Ritchey     1
# Name: Trainer, dtype: int64

# %% [markdown]
# How often, or at all, did a pair try to compete again after not being succesfull the year together before?

# %%
#df3.loc[df3.race == 'Kentucky Derby','Jockey'].value_counts()
#df3['Jockey'].value_counts()
horse_jockey_pair = df3[["year", "race", "final_place", "Horse", "Jockey"]]
horse_jockey_pair.drop_duplicates(subset= ["Horse","Jockey"], keep = "first")
horse_jockey_pair.tail()
# Out:
#      year       race  final_place             Horse           Jockey
# 622  2005  Preakness           10          High Fly  Jerry D. Bailey
# 623  2005  Preakness           11       Hal's Image      Jose Santos
# 624  2005  Preakness           12             Wilko   Corey Kakatani
# 625  2005  Preakness           13  Galloping Grocer        Joe Bravo
# 626  2005  Preakness           14        Going Wild   Robby Albarado

# %% [markdown]
# Is it even possible to have two Ys for one X?
# First let's make PP work for Y and then see if final_place can work for Y. But can a horse's name be a place to plot?

# %%
fig, graph1 = plt.subplots()
graph1 = sns.swarmplot(x="Horse", y="final_place", data=banana)
plt.xticks(rotation=90)
plt.show()
